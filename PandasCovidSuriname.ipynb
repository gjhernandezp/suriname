# %% [markdown]
# ## Importing the pandas and ploting libray

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Downloading and reading the covid data file

# %%
# Download an updated file from 
# https://ourworldindata.org/coronavirus-source-data 
# Quantopian 
#      - put it into your data directory in research (notebooks) 
#      - to read data = local_csv('owid-covid-data.csv') 
# Colab
#      - put it into your contents directory 
#      - to read data = pd.read_csv("owid-covid-data.csv")
data = local_csv('owid-covid-data.csv') 
data
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 0          ABW          Aruba  2020-03-13            2          2
# 1          ABW          Aruba  2020-03-20            4          2
# 2          ABW          Aruba  2020-03-24           12          8
# 3          ABW          Aruba  2020-03-25           17          5
# 4          ABW          Aruba  2020-03-26           19          2
# 5          ABW          Aruba  2020-03-27           28          9
# 6          ABW          Aruba  2020-03-28           28          0
# 7          ABW          Aruba  2020-03-29           28          0
# 8          ABW          Aruba  2020-03-30           50         22
# 9          ABW          Aruba  2020-04-01           55          5
# 10         ABW          Aruba  2020-04-02           55          0
# 11         ABW          Aruba  2020-04-03           60          5
# 12         ABW          Aruba  2020-04-04           62          2
# ...

# %% [markdown]
# ## Extracting a column

# %%
iso = data['iso_code']
iso
# Out:
# 0        ABW
# 1        ABW
# 2        ABW
# 3        ABW
# 4        ABW
# 5        ABW
# 6        ABW
# 7        ABW
# 8        ABW
# 9        ABW
# 10       ABW
# 11       ABW
# 12       ABW
# 13       ABW
# 14       ABW
# 15       ABW
# 16       ABW
# 17       ABW
# 18       ABW
# 19       ABW
# 20       ABW
# 21       ABW
# 22       ABW
# 23       ABW
# 24       ABW
# 25       ABW
# 26       ABW
# 27       ABW
# 28       ABW
# 29       ABW
#         ...
# 21786    NaN
# 21787    NaN
# 21788    NaN
# 21789    NaN
# 21790    NaN
# 21791    NaN
# 21792    NaN
# 21793    NaN
# 21794    NaN
# 21795    NaN
# 21796    NaN
# 21797    NaN
# 21798    NaN
# 21799    NaN
# 21800    NaN
# 21801    NaN
# 21802    NaN
# 21803    NaN
# 21804    NaN
# 21805    NaN
# 21806    NaN
# 21807    NaN
# 21808    NaN
# 21809    NaN
# 21810    NaN
# 21811    NaN
# 21812    NaN
# 21813    NaN
# 21814    NaN
# 21815    NaN
# Name: iso_code, dtype: object

# %% [markdown]
# ## Extracting multiple columns

# %%
date_and_iso = data[['date','iso_code']]
date_and_iso
# Out:
#              date iso_code
# 0      2020-03-13      ABW
# 1      2020-03-20      ABW
# 2      2020-03-24      ABW
# 3      2020-03-25      ABW
# 4      2020-03-26      ABW
# 5      2020-03-27      ABW
# 6      2020-03-28      ABW
# 7      2020-03-29      ABW
# 8      2020-03-30      ABW
# 9      2020-04-01      ABW
# 10     2020-04-02      ABW
# 11     2020-04-03      ABW
# 12     2020-04-04      ABW
# 13     2020-04-05      ABW
# 14     2020-04-06      ABW
# 15     2020-04-07      ABW
# 16     2020-04-08      ABW
# 17     2020-04-09      ABW
# 18     2020-04-10      ABW
# 19     2020-04-11      ABW
# 20     2020-04-12      ABW
# 21     2020-04-13      ABW
# 22     2020-04-14      ABW
# 23     2020-04-15      ABW
# 24     2020-04-16      ABW
# 25     2020-04-17      ABW
# 26     2020-04-18      ABW
# 27     2020-04-19      ABW
# 28     2020-04-20      ABW
# 29     2020-04-21      ABW
# ...           ...      ...
# 21786  2020-02-03      NaN
# 21787  2020-02-04      NaN
# ...

# %% [markdown]
# ## Seting column as index

# %%
date_and_iso = date_and_iso.set_index('date')
date_and_iso
# Out:
#            iso_code
# date
# 2020-03-13      ABW
# 2020-03-20      ABW
# 2020-03-24      ABW
# 2020-03-25      ABW
# 2020-03-26      ABW
# 2020-03-27      ABW
# 2020-03-28      ABW
# 2020-03-29      ABW
# 2020-03-30      ABW
# 2020-04-01      ABW
# 2020-04-02      ABW
# 2020-04-03      ABW
# 2020-04-04      ABW
# 2020-04-05      ABW
# 2020-04-06      ABW
# 2020-04-07      ABW
# 2020-04-08      ABW
# 2020-04-09      ABW
# 2020-04-10      ABW
# 2020-04-11      ABW
# 2020-04-12      ABW
# 2020-04-13      ABW
# 2020-04-14      ABW
# 2020-04-15      ABW
# 2020-04-16      ABW
# 2020-04-17      ABW
# 2020-04-18      ABW
# 2020-04-19      ABW
# 2020-04-20      ABW
# 2020-04-21      ABW
# ...             ...
# 2020-02-03      NaN
# 2020-02-04      NaN
# 2020-02-05      NaN
# 2020-02-06      NaN
# 2020-02-07      NaN
# 2020-02-08      NaN
# 2020-02-09      NaN
# 2020-02-10      NaN
# 2020-02-11      NaN
# 2020-02-12      NaN
# 2020-02-13      NaN
# 2020-02-14      NaN
# 2020-02-15      NaN
# ...

# %% [markdown]
# ## Extracting all columns wint a condition in column

# %%
dataaruba = data[data['location'] == "Aruba"]
dataaruba
# Out:
#    iso_code location        date  total_cases  new_cases  total_deaths  \
# 0       ABW    Aruba  2020-03-13            2          2             0
# 1       ABW    Aruba  2020-03-20            4          2             0
# 2       ABW    Aruba  2020-03-24           12          8             0
# 3       ABW    Aruba  2020-03-25           17          5             0
# 4       ABW    Aruba  2020-03-26           19          2             0
# 5       ABW    Aruba  2020-03-27           28          9             0
# 6       ABW    Aruba  2020-03-28           28          0             0
# 7       ABW    Aruba  2020-03-29           28          0             0
# 8       ABW    Aruba  2020-03-30           50         22             0
# 9       ABW    Aruba  2020-04-01           55          5             0
# 10      ABW    Aruba  2020-04-02           55          0             0
# 11      ABW    Aruba  2020-04-03           60          5             0
# ...

# %%
total_deaths_aruba = data[data['location'] == "Aruba"][['date','total_deaths' ]]
total_deaths_aruba = total_deaths_aruba.set_index('date')
total_deaths_aruba.plot()
plt.title('Covid 19 Aruba')
plt.xlabel('date')
plt.ylabel('total_deaths')
plt.legend(loc=0)

# %%
total_cases_aruba = data[data['location'] == "Aruba"][['date','total_cases' ]]
total_cases_aruba = total_cases_aruba .set_index('date')
total_cases_aruba.plot()
plt.title('Covid 19 Aruba')
plt.xlabel('date')
plt.ylabel('total_cases')
plt.legend(loc=0)

# %% [markdown]
# ## Now do the same for Suriname
